# %% [markdown]
# # q1: Current version of apps are always better then the previous ones?
# ## find out here:
#
# https://public.tableau.com/profile/beatriz.renault4897#!/vizhome/Book1-Applestore/Story1?publish=yes

# %%
import pandas as pd
import numpy as np

# %%
description = pd.read_csv('/Users/beatrizrenault/Documents/IH_DATA/DATASETS/app-store-apple-data-set-10k-apps/appleStore_description.csv')
description.head(5) #app description
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#                                             app_desc
# 0  SAVE 20%, now only $3.99 for a limited time!\n...
# 1  Let Evernote change the way you organize your ...
# 2  Download the most popular free weather app pow...
# 3  The eBay app is the best way to find anything ...
# 4  On more than 250 million devices around the wo...

# %%
applestore = pd.read_csv('/Users/beatrizrenault/Documents/IH_DATA/DATASETS/app-store-apple-data-set-10k-apps/AppleStore.csv')
applestore.head(5) #dataset
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %% [markdown]
# # Drop columns

# %%
applestore.columns
#DataFrame.drop(self, labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise'
applestore.drop(columns = ['sup_devices.num','ipadSc_urls.num', 'lang.num', 'vpp_lic'], inplace=True)
applestore
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %% [markdown]
# # Check for correlations

# %%
applestore.dtypes
#applestore.describe()
#applestore[']

# %%
corrMatrix = applestore.corr()
corrMatrix
# Out:
#                   Unnamed: 0        id  size_bytes     price  \
# Unnamed: 0          1.000000  0.910714    0.041277 -0.074326
# id                  0.910714  1.000000    0.077486 -0.075247
# size_bytes          0.041277  0.077486    1.000000  0.182392
# price              -0.074326 -0.075247    0.182392  1.000000
# rating_count_tot   -0.168640 -0.201976    0.004486 -0.039044
# rating_count_ver   -0.064717 -0.072784    0.006337 -0.018012
# user_rating        -0.204867 -0.185178    0.066256  0.046601
# user_rating_ver    -0.127580 -0.109849    0.086075  0.025173
#
#                   rating_count_tot  rating_count_ver  user_rating  \
# Unnamed: 0               -0.168640         -0.064717    -0.204867
# id                       -0.201976         -0.072784    -0.185178
# size_bytes                0.004486          0.006337     0.066256
# price                    -0.039044         -0.018012     0.046601
# rating_count_tot          1.000000          0.163645     0.083310
# ...

# %%
import matplotlib.pyplot as plt
#matplotlib.pyplot.subplots(nrows=1, ncols=1, sharex=False, sharey=False, squeeze=True, subplot_kw=None, 
#gridspec_kw=None, **fig_kw)[source]

fig, axs = plt.subplots(nrows=2, ncols=2, sharey=True)

#line 1
#axs[0,0].hist(applestore.size_bytes)
#axs[0,1].hist(applestore.price)

#line 2
#axs[1,0].hist(applestore.rating_count_tot)
#axs[1,1].hist(applestore.rating_count_ver)

#line 3
axs[0,0].hist(applestore.user_rating)
axs[0,1].hist(applestore.user_rating_ver)
# Out:
# (array([1443.,    0.,  125.,   74.,  136.,  176.,  304.,  533., 1237.,
#         3169.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %%
applestore.rating_count_tot.max()
applestore.rating_count_tot.min()
# Out:
# 0

# %%
applestore.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre
# ...

# %%
test = applestore.groupby(['prime_genre']).count()
test
# Out:
#                    Unnamed: 0    id  track_name  size_bytes  currency  price  \
# prime_genre
# Book                      112   112         112         112       112    112
# Business                   57    57          57          57        57     57
# Catalogs                   10    10          10          10        10     10
# Education                 453   453         453         453       453    453
# Entertainment             535   535         535         535       535    535
# Finance                   104   104         104         104       104    104
# Food & Drink               63    63          63          63        63     63
# Games                    3862  3862        3862        3862      3862   3862
# Health & Fitness          180   180         180         180       180    180
# Lifestyle                 144   144         144         144       144    144
# Medical                    23    23          23          23        23     23
# ...
