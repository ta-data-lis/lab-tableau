# %%
import pandas as pd
import numpy as np

# %%
#

apple = pd.read_csv('AppleStore.csv', error_bad_lines=False)  #Error tokenizing data. C error: Expected 1 fields in line 913, saw 15
apple.head()
# Out:
# b'Skipping line 913: expected 1 fields, saw 15\nSkipping line 1219: expected 1 fields, saw 15\n'
#   ,"id","track_name","size_bytes","currency","price","rating_count_tot","rating_count_ver","user_rating","user_rating_ver","ver","cont_rating","prime_genre","sup_devices.num","ipadSc_urls.num","lang.num","vpp_lic";
# 0  1,"281656475","PAC-MAN Premium",100788224,"USD...
# 1  2,"281796108","Evernote - stay organized",1585...
# 2  3,"281940292","WeatherBug - Local Weather, Rad...
# 3  4,"282614216","eBay: Best App to Buy, Sell, Sa...
# 4  5,"282935706","Bible",92774400,"USD",0,985920,...

# %%
apple = pd.read_csv('AppleStore.csv', delimiter=",", encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-29-68412c50f28f> in <module>
# ----> 1 apple = pd.read_csv('AppleStore.csv', delimiter=",", encoding='utf-8')
#
# ~\Anaconda3\envs\IronHack1\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
#as i could not use the dataset above, i decided to use the other one that we already had (that i think that is the same.)

apple = pd.read_csv('AppleStore.csv')
apple.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
apple
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
#takeing a look in the dataset:

apple.columns
# Out:
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
apple.dtypes
# Out:
# Unnamed: 0            int64
# id                    int64
# track_name           object
# size_bytes            int64
# currency             object
# price               float64
# rating_count_tot      int64
# rating_count_ver      int64
# user_rating         float64
# user_rating_ver     float64
# ver                  object
# cont_rating          object
# prime_genre          object
# sup_devices.num       int64
# ipadSc_urls.num       int64
# lang.num              int64
# vpp_lic               int64
# dtype: object

# %%
apple.describe()
# Out:
#          Unnamed: 0            id    size_bytes        price  \
# count   7197.000000  7.197000e+03  7.197000e+03  7197.000000
# mean    4759.069612  8.631310e+08  1.991345e+08     1.726218
# std     3093.625213  2.712368e+08  3.592069e+08     5.833006
# min        1.000000  2.816565e+08  5.898240e+05     0.000000
# 25%     2090.000000  6.000937e+08  4.692275e+07     0.000000
# 50%     4380.000000  9.781482e+08  9.715302e+07     0.000000
# 75%     7223.000000  1.082310e+09  1.819249e+08     1.990000
# max    11097.000000  1.188376e+09  4.025970e+09   299.990000
#
#        rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# count      7.197000e+03       7197.000000  7197.000000      7197.000000
# mean       1.289291e+04        460.373906     3.526956         3.253578
# std        7.573941e+04       3920.455183     1.517948         1.809363
# min        0.000000e+00          0.000000     0.000000         0.000000
# ...

# %%
apple.isnull().sum()
# Out:
# Unnamed: 0          0
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# dtype: int64

# %%
apple['prime_genre'].unique()
# Out:
# array(['Games', 'Productivity', 'Weather', 'Shopping', 'Reference',
#        'Finance', 'Music', 'Utilities', 'Travel', 'Social Networking',
#        'Sports', 'Business', 'Health & Fitness', 'Entertainment',
#        'Photo & Video', 'Navigation', 'Education', 'Lifestyle',
#        'Food & Drink', 'News', 'Book', 'Medical', 'Catalogs'],
#       dtype=object)

# %%
apple['prime_genre'].value_counts()
# Out:
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Shopping              122
# Sports                114
# Book                  112
# Finance               104
# Travel                 81
# News                   75
# Weather                72
# Reference              64
# Food & Drink           63
# Business               57
# Navigation             46
# Medical                23
# Catalogs               10
# Name: prime_genre, dtype: int64

# %%
apple['track_name'].unique()
# Out:
# array(['PAC-MAN Premium', 'Evernote - stay organized',
#        'WeatherBug - Local Weather, Radar, Maps, Alerts', ...,
#        'Bret Michaels Emojis + Lyric Keyboard',
#        'VR Roller Coaster World - Virtual Reality',
#        'Escape the Sweet Shop Series'], dtype=object)

# %%
#apple['track_name'].value_counts()

# %%
apple['price'].unique()
# Out:
# array([  3.99,   0.  ,   0.99,   9.99,   4.99,   7.99,   2.99,   1.99,
#          5.99,  12.99,  21.99, 249.99,   6.99,  74.99,  19.99,   8.99,
#         24.99,  13.99,  14.99,  16.99,  47.99,  11.99,  59.99,  15.99,
#         27.99,  17.99, 299.99,  49.99,  23.99,  20.99,  39.99,  99.99,
#         29.99,  34.99,  18.99,  22.99])

# %%
apple['currency'].unique()
# Out:
# array(['USD'], dtype=object)

# %%
apple['rating_count_tot'].unique()
# Out:
# array([ 21292, 161065, 188583, ...,    283,   3384,   1441], dtype=int64)

# %%
apple.pivot_table(values=["price"],index=["prime_genre"],aggfunc=["mean"],fill_value=0)
# Out:
#                        mean
#                       price
# prime_genre
# Book               1.790536
# Business           5.116316
# Catalogs           0.799000
# Education          4.028234
# Entertainment      0.889701
# Finance            0.421154
# Food & Drink       1.552381
# Games              1.432923
# Health & Fitness   1.916444
# Lifestyle          0.885417
# Medical            8.776087
# Music              4.835435
# Navigation         4.124783
# News               0.517733
# Photo & Video      1.473295
# Productivity       4.330562
# Reference          4.836875
# Shopping           0.016311
# Social Networking  0.339880
# Sports             0.953070
# Travel             1.120370
# Utilities          1.647621
# Weather            1.605417

# %%
apple_clean= apple.pivot_table(values=["price", "rating_count_tot"],index=["prime_genre"],aggfunc=["mean", "sum", "count"],fill_value=0, ) 
apple_clean
# Out:
#                        mean                       sum                  count  \
#                       price rating_count_tot    price rating_count_tot price
# prime_genre
# Book               1.790536      5125.437500   200.54           574049   112
# Business           5.116316      4788.087719   291.63           272921    57
# Catalogs           0.799000      1732.500000     7.99            17325    10
# Education          4.028234      2239.229581  1824.79          1014371   453
# Entertainment      0.889701      7533.678505   475.99          4030518   535
# Finance            0.421154     11047.653846    43.80          1148956   104
# Food & Drink       1.552381     13938.619048    97.80           878133    63
# Games              1.432923     13691.996634  5533.95         52878491  3862
# Health & Fitness   1.916444      9913.172222   344.96          1784371   180
# Lifestyle          0.885417      6161.763889   127.50           887294   144
# ...

# %%
# Count:
#Games                3862
#Entertainment         535
#Education             453

# %%
apple_clean.to_csv('Aple_clean.csv')
apple_clean
# Out:
#                        mean                       sum                  count  \
#                       price rating_count_tot    price rating_count_tot price
# prime_genre
# Book               1.790536      5125.437500   200.54           574049   112
# Business           5.116316      4788.087719   291.63           272921    57
# Catalogs           0.799000      1732.500000     7.99            17325    10
# Education          4.028234      2239.229581  1824.79          1014371   453
# Entertainment      0.889701      7533.678505   475.99          4030518   535
# Finance            0.421154     11047.653846    43.80          1148956   104
# Food & Drink       1.552381     13938.619048    97.80           878133    63
# Games              1.432923     13691.996634  5533.95         52878491  3862
# Health & Fitness   1.916444      9913.172222   344.96          1784371   180
# Lifestyle          0.885417      6161.763889   127.50           887294   144
# ...

# %%
#questions:

Main: 
Does price impact the use of apps? 
    
Sub:

What are the best app genres considering price and total rate?

# %% [markdown]
# #answers:
#
# Main and Sub:
# The graph with the average 'price x average score', shows that the app of the medical genre are the most expensive
# and the last in the total average rating.
# Medical is the last one in count as well, it could be because of the price, but at the same time it could be because
# we are talking about a small target.
# When we compare the sum of the rate relative to some price, the genre Medical apear with the worse rate and in 11 position in higher price.
#
# In the first position when we avaluate sum of rate and price is the genre Games, which are also the most downloaded apps, and appear in 14 position
# with average price per app.
#
# Despite the large volume of apps in the Games category, this is the best one considering rate, price and quantity.

# %% [markdown]
# https://public.tableau.com/profile/gabriela.scatena.clemente#!/vizhome/Apple_tableau-comparativebetweengenres/Histria1?publish=yes

# %% [markdown]
# Probably to draw conclusions, the ideal would be to separate the dataset taking into account the apps that are paid and those that are not, and also to clean it up in order to better understand which apps are in each category.
# I also believe that both my question and my answers are very shallow and without many conclusions, sorry.
